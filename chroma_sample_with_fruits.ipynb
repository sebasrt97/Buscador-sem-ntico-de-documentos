# %% [markdown]
# # ChromaDB Getting Started
#
# https://docs.trychroma.com/getting-started

# %% [markdown]
# ## Install

# %%
# !pip install chromadb

# %% [markdown]
# ## Create a Chroma Client

# %%
import chromadb
chroma_client = chromadb.Client()

# %% [markdown]
# ## Create a collection
#
# Collections are where you'll store your embeddings, documents, and any additional metadata. You can create a collection with a name:

# %%
#collection = chroma_client.create_collection(name="my_collection")
collection = chroma_client.create_collection(name="words")

# %% [markdown]
# ## Add some text documents to the collection
#
# Chroma will store your text and handle embedding and indexing automatically. You can also customize the embedding model.

# %%
collection.add(
    documents = ["apple","peach","phone","music"],
    ids = ["id1", "id2", "id3", "id4"]
)
# Out:
# /home/bigdata/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [02:21<00:00, 589kiB/s]

# %% [markdown]
# ## Query the collection
#
# You can query the collection with a list of query texts, and Chroma will return the n most similar results. It's that easy!

# %%
results = collection.query(
    query_texts=["fruit"],
    n_results=4
)

results
# Out:
# {'ids': [['id2', 'id1', 'id3', 'id4']],
#  'embeddings': None,
#  'documents': [['peach', 'apple', 'phone', 'music']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None, None, None]],
#  'distances': [[0.6450808644294739,
#    0.9255111217498779,
#    1.1451698541641235,
#    1.280678153038025]]}

# %%
results = collection.query(
    query_texts=["fruit"],
    n_results=1
)

results
# Out:
# {'ids': [['id2']],
#  'embeddings': None,
#  'documents': [['peach']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None]],
#  'distances': [[0.6450808644294739]]}

# %%
results = collection.query(
    query_texts=["art"],
    n_results=1
)

results
# Out:
# {'ids': [['id4']],
#  'embeddings': None,
#  'documents': [['music']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None]],
#  'distances': [[0.9536923766136169]]}

# %%
results = collection.query(
    query_texts=["i'm feeling hungry"],
    n_results=1
)

results
# Out:
# {'ids': [['id2']],
#  'embeddings': None,
#  'documents': [['peach']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None]],
#  'distances': [[1.534833550453186]]}

# %%
results = collection.query(
    query_texts=["i would like to talk with someone"],
    n_results=1
)

results["documents"]
# Out:
# [['phone']]

# %%
## View the embeddings for a document

# %%
document_id = "id1"
result = collection.get(ids=[document_id], include=["embeddings"])
embeddings = result["embeddings"][0]  # embeddings of the specified document

# %%
embeddings
# Out:
# array([-6.13850448e-03,  3.10117602e-02,  6.47936091e-02,  1.09414663e-02,
#         5.26720192e-03, -4.74764630e-02,  8.12030360e-02,  2.89809778e-02,
#         6.67619333e-02,  3.03004198e-02,  5.74649572e-02, -8.62358045e-03,
#         1.32275408e-03,  3.99159238e-04, -1.88430380e-02, -2.57937927e-02,
#        -1.30420616e-02, -5.26249781e-02, -5.82925230e-02, -2.58992203e-02,
#        -3.33736651e-02,  2.45679412e-02, -5.22656227e-03,  2.30059307e-02,
#         3.28607410e-02,  7.50218108e-02,  5.80181414e-03, -1.49586303e-02,
#        -2.87529118e-02, -1.18551835e-01, -3.93217169e-02, -5.13875559e-02,
#         7.66181946e-02,  4.84036915e-02, -3.02564390e-02, -9.14341584e-02,
#         5.11821583e-02, -9.64969490e-03, -2.15108246e-02, -7.17740878e-02,
#        -6.32242411e-02, -1.76688489e-02,  2.80814338e-02,  9.00471210e-02,
#         1.94179155e-02,  5.45441918e-03,  4.83017750e-02,  8.49087723e-03,
#         2.77505443e-02,  9.65605676e-02,  2.63026636e-02, -3.05333398e-02,
#        -6.88157380e-02, -6.03408460e-03, -5.67501038e-03,  7.89147150e-03,
#        -1.21500231e-02,  3.05108577e-02,  8.95909816e-02,  5.56778163e-02,
#         2.40891390e-02, -1.07354291e-01, -3.34600471e-02,  4.51374277e-02,
#         3.04723624e-02, -1.31435888e-02, -4.74775136e-02, -1.83024239e-02,
#        -5.73382378e-02, -6.68075681e-02,  3.15415859e-02, -1.90293323e-02,
#         5.13307415e-02,  5.28617911e-02,  2.08306238e-02,  1.05778165e-02,
#         7.54231811e-02, -5.76457120e-02, -4.97330958e-03, -2.09310297e-02,
#        -2.75612269e-02,  1.45159671e-02, -1.07568182e-01,  4.48357910e-02,
#         2.29100082e-02, -2.66433842e-02, -4.83908877e-02,  2.04160698e-02,
#        -6.73845112e-02,  1.24963867e-02, -6.56791031e-02,  4.35093231e-02,
#         4.62106019e-02, -3.23691852e-02, -3.54240797e-02,  1.62200052e-02,
#         1.18146441e-03, -7.76381716e-02, -9.47551653e-02,  2.23830640e-01,
#         1.23826833e-02,  4.64599803e-02,  1.32103479e-02,  2.49246825e-02,
#         6.35972917e-02, -6.58840463e-02, -7.70298019e-02,  1.52155384e-02,
#         2.56610718e-02,  9.94232148e-02,  4.65780236e-02, -7.90902227e-02,
#        -1.19720876e-01,  2.01226100e-02,  2.80200392e-02, -4.30080444e-02,
#        -2.59482935e-02,  7.57106021e-02,  5.85722588e-02, -2.25218609e-02,
#        -3.29331458e-02,  5.91354929e-02, -9.75374226e-03, -3.62300389e-02,
#        -1.03333853e-01, -1.84598230e-02, -3.20192091e-02, -4.27504263e-33,
#         2.99247541e-03, -1.92890447e-02,  4.22348082e-02, -2.31308602e-02,
#        -4.65582050e-02, -4.27305028e-02,  7.21698767e-03,  6.61647543e-02,
#        -5.43037383e-03,  3.61810364e-02, -3.71122770e-02, -2.91622803e-02,
#        -8.02596211e-02, -5.58772031e-03,  1.60861269e-01, -2.45417301e-02,
#        -1.37140416e-02,  7.90828839e-03, -5.15232235e-02,  2.70250393e-03,
#        -2.00329302e-03, -1.34354178e-02, -2.10344399e-04,  2.92833187e-02,
#        -5.77626079e-02, -5.65803573e-02,  2.45778132e-02, -6.47813976e-02,
#         7.40576759e-02, -6.41894818e-04, -1.45088226e-04,  1.44529464e-02,
#         1.35063669e-02, -1.17302001e-01, -4.58576083e-02, -3.39333080e-02,
#         7.17597222e-03, -5.15011102e-02,  6.25661388e-02,  3.15965340e-02,
#        -9.70773548e-02, -1.93387608e-03,  3.80738936e-02,  8.52581114e-03,
#         8.88990164e-02,  2.68261861e-02,  4.19648923e-03,  6.28506020e-02,
#        -3.89664434e-02,  3.45033668e-02, -9.54605117e-02, -1.39406892e-02,
#         5.42690903e-02,  8.14356841e-03, -3.80860604e-02, -1.25879478e-02,
#         4.03869152e-02,  5.22137852e-03,  6.71426300e-03,  4.40495014e-02,
#         3.42584914e-03,  9.34836492e-02,  1.53205814e-02,  6.06894717e-02,
#        -4.64338735e-02,  7.90697634e-02,  6.06144853e-02, -3.94291803e-02,
#        -6.77470416e-02,  6.69754446e-02, -5.91841452e-02,  3.18911741e-03,
#         4.87666354e-02, -2.46904902e-02, -6.33931682e-02, -1.13948795e-03,
#        -4.02782969e-02,  8.96312576e-03, -8.83468911e-02, -2.10988987e-02,
#        -4.65345867e-02,  3.56327253e-03, -1.15670753e-03,  1.10653505e-01,
#        -2.20952071e-02,  6.57154247e-02, -5.76503873e-02, -4.03510891e-02,
#         2.67296899e-02,  6.31631911e-02, -8.54093656e-02,  1.35379164e-02,
#         1.12292469e-02, -3.29936808e-03, -7.63426125e-02,  2.89998038e-33,
#        -4.05141339e-02, -1.06743515e-01, -1.29067693e-02,  1.62407923e-02,
#         3.23874354e-02, -4.25311625e-02, -2.07376815e-02,  2.37796120e-02,
#        -1.09621309e-01,  1.14260083e-02, -2.70516388e-02, -7.70637346e-03,
#         7.26969391e-02, -2.46187542e-02, -2.13322863e-02,  4.92010564e-02,
#         1.24535887e-02, -3.81896347e-02,  3.34784538e-02, -7.35005829e-04,
#        -2.03176774e-02, -1.38497027e-02,  4.91495840e-02,  2.04118504e-03,
#        -1.26967803e-02, -2.58603226e-02,  4.81920727e-02,  3.96005213e-02,
#        -1.86379836e-03,  3.09784967e-03,  3.46065238e-02, -4.94678542e-02,
#         4.75732982e-03,  3.95609848e-02,  6.64726719e-02,  9.45493504e-02,
#        -4.23850119e-02, -2.66848262e-02,  2.08671503e-02, -4.04097252e-02,
#         8.40569958e-02,  4.79122214e-02,  2.50427611e-02,  1.26171172e-01,
#         2.07272694e-02,  1.98999941e-02, -6.68115318e-02,  9.05478075e-02,
#         7.20644146e-02, -1.49755999e-02, -2.76096612e-02, -1.69962626e-02,
#        -1.84985343e-02, -4.80833650e-02, -7.54146203e-02, -6.05264772e-03,
#         8.14709812e-03,  1.34750726e-02,  1.84109136e-02, -1.54399574e-02,
#         2.25823838e-02, -2.78019942e-02,  5.05669601e-02, -4.14640568e-02,
#        -7.91969299e-02, -2.39058919e-02,  4.23179530e-02,  4.18637320e-02,
#        -6.52034730e-02,  5.78033067e-02,  1.15746491e-01,  1.38644893e-02,
#         1.88187715e-02, -2.10135411e-02, -5.91864213e-02,  4.65148687e-02,
#        -4.22595255e-03,  2.74932515e-02, -5.98427877e-02, -4.67933714e-02,
#         1.02170549e-01,  1.17360018e-01,  5.67140151e-03,  8.58062059e-02,
#         3.93267497e-02,  2.56064516e-02,  3.47414240e-02,  9.48777015e-04,
#        -1.57679990e-02,  3.46629545e-02, -2.88793966e-02,  1.01079950e-02,
#        -3.60536762e-02, -9.04881768e-03, -1.27672210e-01, -1.15697674e-08,
#         1.84855741e-02, -3.61233130e-02,  7.21341968e-02, -2.57241223e-02,
#         3.05710677e-02,  5.12345880e-02,  3.96113619e-02,  6.04291493e-03,
#         8.70836228e-02,  1.51468592e-03, -2.79443339e-02, -4.50792536e-02,
#        -6.97890371e-02,  6.11441247e-02,  3.47282588e-02,  1.86884757e-02,
#        -5.33657102e-03,  7.05939159e-02,  1.98606607e-02, -2.56423187e-02,
#        -6.87363669e-02,  5.11690862e-02,  1.80766024e-02, -3.45643833e-02,
#        -2.62892083e-03, -2.64911223e-02,  4.30884585e-02,  2.80680098e-02,
#         5.97266667e-02,  3.83455716e-02, -3.22097652e-02,  1.46194790e-02,
#        -3.85751948e-02, -1.71351805e-02, -5.13715036e-02, -9.15951654e-02,
#        -4.28121351e-02,  2.74312831e-02, -6.35621650e-03, -3.08591556e-02,
#        -3.62817533e-02, -3.64000984e-02,  9.55109112e-03, -6.05615787e-02,
#        -6.51328415e-02, -8.94512087e-02, -7.62849301e-03, -4.18602079e-02,
#        -9.50539205e-03,  1.01591714e-01,  7.95124285e-03, -1.01354327e-02,
#         7.82497823e-02,  3.91543955e-02,  1.36080720e-02, -1.92693193e-02,
#         2.13735793e-02, -9.98961851e-02, -6.72821328e-02,  7.65504092e-02,
#         1.60245389e-01, -4.81897816e-02,  7.35201016e-02,  8.95386785e-02])
